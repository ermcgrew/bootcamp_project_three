# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
from webdriver_manager.chrome import ChromeDriverManager
from splinter import Browser

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# There is no [win32] chromedriver for browser  in cache
# Trying to download new driver from https://chromedriver.storage.googleapis.com/97.0.4692.71/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\ermcg\.wdm\drivers\chromedriver\win32\97.0.4692.71]

# %%
# Visit houseplantsexpert.com website
url = 'https://www.houseplantsexpert.com/a-z-list-of-house-plants.html'
browser.visit(url)
# time.sleep(5)

# %% [markdown]
# # Screen-scraping

# %%
html = browser.html
soup = bs(html, "html.parser")

#Scraping the webpage to pull the url for individual plants
plant_url = []

i = 0

for i in range(1,4):
    count = 0
    datas = soup.find('ul', class_="pagination"+str(i))
    for result in datas.find_all('a'):
        url = result.get('href')
        plant_url.append(url)
    
plant_url
# Out:
# ['https://www.houseplantsexpert.com/hippeastrum-amaryllis.html',
#  'https://www.houseplantsexpert.com/african-violet-care-information.html',
#  'https://www.houseplantsexpert.com/angel-wing-begonia.html',
#  'https://www.houseplantsexpert.com/barberton-daisy.html',
#  'https://www.houseplantsexpert.com/beach-spider-lily.html',
#  'https://www.houseplantsexpert.com/growing-belladonna-lily-plants-indoors.html',
#  'https://www.houseplantsexpert.com/bird-of-paradise-plant.html',
#  'https://www.houseplantsexpert.com/blushing-bromeliad.html',
#  'https://www.houseplantsexpert.com/busy-lizzie.html',
#  'https://www.houseplantsexpert.com/growing-calla-lilly-plants-indoors-and-care.html',
#  'https://www.houseplantsexpert.com/coral-berry-plant.html',
#  'https://www.houseplantsexpert.com/cattleya-corsage-orchids.html',
#  'https://www.houseplantsexpert.com/cyclamen-persicum.html',
#  'https://www.houseplantsexpert.com/eternal-flame-calathea-crocata.html',
#  'https://www.houseplantsexpert.com/false-shamrock-plant.html',
#  'https://www.houseplantsexpert.com/flamingo-flower.html',
#  'https://www.houseplantsexpert.com/flaming-sword-bromeliad.html',
#  'https://www.houseplantsexpert.com/flowering-maple.html',
#  'https://www.houseplantsexpert.com/kaffir-lily.html',
#  'https://www.houseplantsexpert.com/lollipop-plant.html',
#  'https://www.houseplantsexpert.com/lycaste-orchid.html',
#  'https://www.houseplantsexpert.com/madagascar-jasmine.html',
#  'https://www.houseplantsexpert.com/tillandsia-caput-medusae.html',
#  'https://www.houseplantsexpert.com/moth-orchid.html',
#  'https://www.houseplantsexpert.com/ornamental-pepper-plant.html',
#  'https://www.houseplantsexpert.com/peace-lily-plant.html',
#  'https://www.houseplantsexpert.com/poinsettia-plant.html',
#  'https://www.houseplantsexpert.com/poison-primrose.html',
#  'https://www.houseplantsexpert.com/queens-tears-plant.html',
#  'https://www.houseplantsexpert.com/rose-of-china.html',
#  'https://www.houseplantsexpert.com/bromeliad-scarlet-star.html',
#  'https://www.houseplantsexpert.com/paphiopedlium-slipper-orchid.html',
#  'https://www.houseplantsexpert.com/the-one-colored-paphiopedilum-concolor.html',
#  'https://www.houseplantsexpert.com/urn-plant.html',
#  'https://www.houseplantsexpert.com/winter-cherry-plant.html',
#  'https://www.houseplantsexpert.com/aluminum-plant.html',
#  'https://www.houseplantsexpert.com/areca-palm.html',
#  'https://www.houseplantsexpert.com/arrowhead-plant.html',
#  'https://www.houseplantsexpert.com/birds-nest-fern.html',
#  'https://www.houseplantsexpert.com/boston-fern-care-indoors.html',
#  'https://www.houseplantsexpert.com/broadleaf-lady-palm.html',
#  'https://www.houseplantsexpert.com/canary-island-date-palm.html',
#  'https://www.houseplantsexpert.com/cast-iron-plant.html',
#  'https://www.houseplantsexpert.com/chinese-evergreen.html',
#  'https://www.houseplantsexpert.com/coral-bead-plant.html',
#  'https://www.houseplantsexpert.com/dracaena-corn-plant.html',
#  'https://www.houseplantsexpert.com/growing-a-creeping-fig-indoors.html',
#  'https://www.houseplantsexpert.com/cretan-brake-fern.html',
#  'https://www.houseplantsexpert.com/codiaeum-variegatum.html',
#  'https://www.houseplantsexpert.com/dumb-cane-plant.html',
#  'https://www.houseplantsexpert.com/amazon-elephants-ear-plant.html',
#  'https://www.houseplantsexpert.com/european-fan-palm.html',
#  'https://www.houseplantsexpert.com/fiddle-leaf-fig.html',
#  'https://www.houseplantsexpert.com/golden-pothos-plant.html',
#  'https://www.houseplantsexpert.com/green-velvet-alocasia.html',
#  'https://www.houseplantsexpert.com/hawaiian-ti-plant.html',
#  'https://www.houseplantsexpert.com/caladium-heart-of-jesus.html',
#  'https://www.houseplantsexpert.com/heartleaf-philodendron.html',
#  'https://www.houseplantsexpert.com/kentia-palm.html',
#  'https://www.houseplantsexpert.com/lucky-bamboo-plant.html',
#  'https://www.houseplantsexpert.com/madagascar-dragon-tree.html',
#  'https://www.houseplantsexpert.com/delta-maidenhair-fern.html',
#  'https://www.houseplantsexpert.com/mexican-fortune-tree.html',
#  'https://www.houseplantsexpert.com/parlor-palm.html',
#  'https://www.houseplantsexpert.com/peacock-plant-calathea-makoyana.html',
#  'https://www.houseplantsexpert.com/pin-stripe-calathea-ornata.html',
#  'https://www.houseplantsexpert.com/pygmy-date-palm.html',
#  'https://www.houseplantsexpert.com/rabbits-foot-fern.html',
#  'https://www.houseplantsexpert.com/rattlesnake-plant.html',
#  'https://www.houseplantsexpert.com/rose-painted-calathea.html',
#  'https://www.houseplantsexpert.com/rubber-plant.html',
#  'https://www.houseplantsexpert.com/sago-palm.html',
#  'https://www.houseplantsexpert.com/sentry-palm.html',
#  'https://www.houseplantsexpert.com/dracaena-song-of-india-plant.html',
#  'https://www.houseplantsexpert.com/spider-plant.html',
#  'https://www.houseplantsexpert.com/swiss-cheese-plant.html',
#  'https://www.houseplantsexpert.com/umbrella-plant.html',
#  'https://www.houseplantsexpert.com/venus-fly-trap-plant.html',
#  'https://www.houseplantsexpert.com/wandering-jew-plant.html',
#  'https://www.houseplantsexpert.com/weeping-fig.html',
#  'https://www.houseplantsexpert.com/zebra-plant.html',
#  'https://www.houseplantsexpert.com/calathea-zebrina.html',
#  'https://www.houseplantsexpert.com/zz-plant.html',
#  'https://www.houseplantsexpert.com/aloe-vera-house-plant.html',
#  'https://www.houseplantsexpert.com/argyroderma-testiculare.html',
#  'https://www.houseplantsexpert.com/baby-rubber-plant-peperomia-obtusifolia.html',
#  'https://www.houseplantsexpert.com/bunny-ear-cactus.html',
#  'https://www.houseplantsexpert.com/century-plant.html',
#  'https://www.houseplantsexpert.com/christmas-cactus.html',
#  'https://www.houseplantsexpert.com/christmas-cheer-sedum-rubrotinctum.html',
#  'https://www.houseplantsexpert.com/coral-cactus.html',
#  'https://www.houseplantsexpert.com/donkeys-tail-plant.html',
#  'https://www.houseplantsexpert.com/easter-cactus.html',
#  'https://www.houseplantsexpert.com/housetree-leek-aeonium-arboreum.html',
#  'https://www.houseplantsexpert.com/flaming-katy.html',
#  'https://www.houseplantsexpert.com/goats-horn-cactus.html',
#  'https://www.houseplantsexpert.com/golden-barrel-cactus.html',
#  'https://www.houseplantsexpert.com/jade-plant.html',
#  'https://www.houseplantsexpert.com/jelly-beans-plant.html',
#  'https://www.houseplantsexpert.com/lithops-fulleri.html',
#  'https://www.houseplantsexpert.com/lithops-optica-rubra.html',
#  'https://www.houseplantsexpert.com/mother-in-laws-tongue.html',
#  'https://www.houseplantsexpert.com/mother-of-thousands-bryophyllum-daigremontianum.html',
#  'https://www.houseplantsexpert.com/orchid-cactus.html',
#  'https://www.houseplantsexpert.com/panda-plant.html',
#  'https://www.houseplantsexpert.com/peperomia-puteolata.html',
#  'https://www.houseplantsexpert.com/peruvian-apple-cactus.html',
#  'https://www.houseplantsexpert.com/peperomia-ferreyrae.html',
#  'https://www.houseplantsexpert.com/rat-tail-cactus.html',
#  'https://www.houseplantsexpert.com/tiger-jaws-faucaria-tigrina.html',
#  'https://www.houseplantsexpert.com/trailing-jade.html',
#  'https://www.houseplantsexpert.com/lithops-pseudotruncatella.html',
#  'https://www.houseplantsexpert.com/watermelon-peperomia.html',
#  'https://www.houseplantsexpert.com/zebra-haworthia.html']

# %%
plant_info=[]

for i in range(0,len(plant_url)):
    try:
        browser.visit(plant_url[i])
        
        plant_dict = {}
        
        html = browser.html
        soup = bs(html, "html.parser")

        plant_data = soup.find_all('div', class_="container")

        #  scraping data and saving it to a dictionary
        plant_dict["origin"] = plant_data[3].find_all('td')[1].text
        plant_dict["Common Name"] = plant_data[3].find_all('td')[3].text.split('common)')[0].split('(')[0].lstrip()
        plant_dict["scientific_name"] = plant_data[3].find_all('td')[3].text.split('common)')[1].split('(')[0].lstrip()
        plant_dict["Max_Growth"] = plant_data[3].find_all('td')[5].text
        plant_dict["Poisonous_for_pets"] = plant_data[3].find_all('td')[7].text
        plant_dict["big_image_url"] = plant_data[3].find_all('img')[0]["src"]
        plant_dict["temperature"] = plant_data[4].find_all('td')[1].text

        print(plant_dict["Common Name"])
        plant_info.append(plant_dict)
#             browser.back()

    except:
        print("error scraping "+ plant_dict["Common Name"])
        browser.back()
browser.quit()
# Out:
# Amaryllis
# African violet
# Angel wing begonia
# Barberton, Gerbera, Transvaal Daisy
# Spider Lily
# Belladonna lily, March lily and naked lady.
# Bird of Paradise, Strelitzia, Crane Flower
# Blushing bromeliad
# Busy Lizzie and Impatient Lucy
# Calla lily
# Coral berry, christmas berry, coral ardisia
# Corsage Orchid
# Cylamen, florist cyclamen
# Eternal Flame
# False shamrock, purple sharock, wood sorrel
# Flamingo flower, pigtail plant
# Flaming Sword
# F. maple,
# Kaffir and bush lily
# Lollipop and golden shrimp plant
# error scraping Lycaste
# Madagascar Jasmine - Wax Flower
# Medusa Plant
# error scraping Moth orchid, Phal
# Christmas and ornamental pepper plant
# error scraping P. lily, Spathe flower
# Poinsettia,
# error scraping Poison or German primrose
# Queens tears, friendship plant
# Rose of China, Chinese hibiscus, Shoe flower
# Scarlet star
# error scraping Slipper Orchid
# The one colored paphiopedilum, lady's slipper
# Urn and pink or silver vase plant
# Winter cherry
# Aluminum Plant
# Areca, butterfly, or cane palm
# Arrowhead Plant or Arrowhead Vine, Goosefoot Plant
# Bird's Nest Fern
# Boston Fern
# Broadleaf lady or little lady palm
# Canary Island Date Palm
# Cast iron plant
# Chinese evergreen
# Coral bead, pin cushion plant
# Corn or cornstalk plant
# Creeping or climbing fig
# Cretan Brake Fern
# Croton, Joseph's coat
# Dumb cane
# Elephant's ear - Alocasia polly - African mask
# European fan, Mediterranean dwarf palm, and Dwarf fan palm
# Fiddle leaf fig tree
# Golden pothos or Devils ivy
# Green Velvet Alocasia, Alocasia Frydek
# Hawaiian ti, good luck, baby doll ti and others
# Heart of Jesus, angel wings, elephant ear, fancy leafed caladium
# error scraping Heart leaf Philodendron, sweetheart plant
# Kentia, paradise, thatch
# Lucky Bamboo
# Dragon Tree
# Delta Maidenhair Nest Fern
# Mexican fortune tree, money tree plant and others
# Parlor, Parlour palm
# error scraping Peacock Plant, Cathedral Windows
# error scraping Pin Stripe Calathea
# Pygmy date, Miniature date palm
# Rabbit's Foot Fern
# Rattlesnake Plant
# Rose Painted Calathea
# Rubber plant or tree, rubber bush
# Sago Palm
# Sentry, belmore sentry, and curly palm
# Song of India, Pleomele
# Spider or airplane
# Swiss cheese or just cheese plant
# Umbrella Plant, Queensland Umbrella Tree, Octupus Tree, Gold Capella
# Venus fly trap
# Wandering Jew, Flowering Inch Plant
# Weeping Fig
# Zebra plant
# Zebra plant
# ZZ plant
# Aloe V, Medicine Plant, True Aloe, Burn Plant,
# Not known
# Baby rubber plant, American rubber plant, Pepper face plant
# Bunny ear and polka-dot cactus
# Century plant, Agave cactus, Maguey, American aloe
# Christmas and holiday cactus
# Christmas cheer, Pork and beans
# Coral cactus
# Donkey's and Burros Tail
# Easter or holiday cactus
# Housetree Leek, Black Rose Tree
# Flaming katy
# Goat's horn cactus
# Golden barrel cactus , golden ball cactus, mother-in-law's cushion
# Jade, money , lucky, friendship
# Jelly beans, Many fingers
# error scraping Lithops pseudotruncatella
# error scraping Lithops optica 'Rubra'
# Mother in law's tongue and snake plant
# error scraping Mother Of Thousands, Devils backbone, Mexican Hat, Evil Genius
# Orchid Cactus
# Panda plant or pussy ears
# Parallel peperomia
# Peruvian apple
# Pincusion Peperomia, Bean Plant
# Rat's Tail
# Tiger Jaws
# Trailing jade, round leaf Peperomia
# Truncate living stone
# error scraping Watermelon Peperomia
# Zebra Haworthia or Zebra Cactus

# %%
plant_info
# Out:
# [{'origin': 'South America.',
#   'Common Name': 'Amaryllis ',
#   'scientific_name': '. Hippeastrum ',
#   'Max_Growth': 'Height 30 in/75 cm.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/hippeastrum-plant.jpg',
#   'temperature': 'The amaryllis within the growing period (winter - spring) prefers temperatures of 70 - 75F°f (21 - 24°c) and from September - November (or early December) 55°f (13°c). After the plant as flowered the temperature can be kept at around 70 - 75F°f (21 - 24°c) which will keep the flower healthier longer.'},
#  {'origin': 'Eastern Africa.',
#   'Common Name': 'African violet ',
#   'scientific_name': '. Saintpaulia ',
#   'Max_Growth': ' Diameter (micro - 3in) - (large - 16in).',
#   'Poisonous_for_pets': 'Non toxic dogs and cats.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/av-light-purple-1.jpg',
#   'temperature': " Room temperatures of around 65°f / 16°c --- 75°f / 24°c are ideal.\nTry not to allow temperatures to decrease lower than 60°f / 15.5°c and it's advised to avoid cold drafts or abrupt temperature changes."},
#  {'origin': 'South America.',
#   'Common Name': 'Angel wing begonia ',
#   'scientific_name': '. Begonia coccinea ',
#   'Max_Growth': '4ft tall or more if not pruned.',
#   'Poisonous_for_pets': 'Toxic for cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/angel_wing_begonia.jpg',
#   'temperature': 'Average room temperatures of 55 - 75°F (13 - 24°C) are best suited for Begonias...and no less than 55°F.'},
#  {'origin': 'South Africa.',
#   'Common Name': 'Barberton, Gerbera, Transvaal Daisy ',
#   'scientific_name': '. -- Gebera Jamesonii ',
#   'Max_Growth': '24in tall.',
#   'Poisonous_for_pets': 'Non toxic for cats, dogs and horses.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/flower_closeup_1.jpg',
#   'temperature': 'Average temperatures of 55 - 75°F (13 - 24°C) are suitable.'},
#  {'origin': 'South Mexico and Central America.',
#   'Common Name': 'Spider Lily ',
#   'scientific_name': '. Hymenocallis littoralis ',
#   'Max_Growth': ' Height 2 - 3ft.',
#   'Poisonous_for_pets': 'No.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/beach_spider_lily_img.jpg',
#   'temperature': 'The Beach Spider Lily is capable of withstanding temperatures that drop into the 40ºF (4°C) range, and as high as 90ºF (32ºC). They must be protected against frosts by all means, or the plant will die back to the bulb stage.'},
#  {'origin': 'South Africa.',
#   'Common Name': 'Belladonna lily, March lily and naked lady. ',
#   'scientific_name': '. Amaryllis belladonna ',
#   'Max_Growth': 'Height 24 in/60 cm.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/amaryllis-belladonna.jpg',
#   'temperature': 'Temperatures from 65 - 75F°f (18 - 24°c) are best suited.'},
#  {'origin': 'South Africa.',
#   'Common Name': 'Bird of Paradise, Strelitzia, Crane Flower ',
#   'scientific_name': '. Strelitzia Reginae ',
#   'Max_Growth': 'Height 6ft (can be kept to 3ft indoors).',
#   'Poisonous_for_pets': 'Mildly toxic for cats, dogs',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/Strelitzia_Reginae_Flower_img1.jpg',
#   'temperature': 'The Bird of Paradise requires moderate temperatures year-round. They can tolerate temperatures as low as 55 ºF (13 ºC), but prefer to remain in the 70-90 ºF (21-32 ºC) range. Above 70 ºF (21 ºC), care instructions do change slightly.'},
#  {'origin': 'South America.',
#   'Common Name': 'Blushing bromeliad ',
#   'scientific_name': '. Neoregelia carolinae ',
#   'Max_Growth': 'Height 18 in/45 cm.',
#   'Poisonous_for_pets': 'Non toxic for cats, dogs',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/blushing_bromeliad1.jpg',
#   'temperature': ' Average to just above average temperatures of 65 - 80ºF (18 - 27ºC) are best suited. Avoid lower than 55ºF (13ºC).'},
#  {'origin': 'East Africa.',
#   'Common Name': 'Busy Lizzie and Impatient Lucy ',
#   'scientific_name': '. -- Impatiens Walleriana ',
#   'Max_Growth': ' 24in (60cm) in height.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/busy-lizzie-plant.jpg',
#   'temperature': 'Average room temperatures from 65°F/18.3°C - 75°F/23.8°C (not below 60°F/15.5°C). '},
#  {'origin': 'South Africa.',
#   'Common Name': 'Calla lily ',
#   'scientific_name': '. -- Zantedeschia aethiopica ',
#   'Max_Growth': 'Flower stalk 3ft (90cm) in height.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/calla-lily-plant.jpg',
#   'temperature': 'These flowers can be rather picky about their temperatures. For ideal growing conditions expose the bulbs to days no hotter than 65°F and no colder than 55°F. The above ground plant can tolerate temperatures as high as 75°F. If your home is hot, use mulch to keep the bulb cooler in its pot.'},
#  {'origin': 'East Asia.',
#   'Common Name': 'Coral berry, christmas berry, coral ardisia ',
#   'scientific_name': '. Ardisia crenata ',
#   'Max_Growth': 'Height 3ft, width 2ft.',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/images/ardisia_crenata1.jpg',
#   'temperature': 'Average warmth is fine of approximately 60-75°F (15-24°C) and no lower than 45°F (8°C).'},
#  {'origin': 'Central and South America.',
#   'Common Name': 'Corsage Orchid ',
#   'scientific_name': '. Cattleya Orchid ',
#   'Max_Growth': '12 - 24in tall.',
#   'Poisonous_for_pets': 'Non toxic for cats, dogs and horses.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/yellow_cattleya_orchid.jpg',
#   'temperature': 'They do well in temperatures varying from 55 degrees at night up to 90 degrees in the day. You can safely put your orchid outside during the summer months. A drop in temperature during the evening is required.'},
#  {'origin': 'Middle East, Greek Islands and elsewhere.',
#   'Common Name': 'Cylamen, florist cyclamen ',
#   'scientific_name': '. -- C. Cyclamen ',
#   'Max_Growth': '12 inches tall',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/cyclamen_flower_bud.jpg',
#   'temperature': 'Cool temperatures from 50°F/10°C - 65°F/18°C are ideal, so a cool room without central heating is required (if you want the flowers to last long). If a room is above these temperatures just find the coolest spot within the room.'},
#  {'origin': 'Brazil.',
#   'Common Name': 'Eternal Flame ',
#   'scientific_name': '. Calathea Crocata ',
#   'Max_Growth': 'Height 1 - 2ft. ',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/calathea_crocata.jpg',
#   'temperature': 'It likes humidity and warmth. Not lower than 60ºF (16ºC). It will do well in a room temperature as long as there is a high level of humidity. The temperature in the room must be stable, and not change much. '},
#  {'origin': 'Brazil.',
#   'Common Name': 'False shamrock, purple sharock, wood sorrel ',
#   'scientific_name': '. -- Oxalis Triangularis [Syn. Oxalis regnellii] ',
#   'Max_Growth': '12in tall.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/false_shamrock_leaf.jpg',
#   'temperature': 'Temperature: Between 60 - 70°F (15 - 21°C) "no higher than 75°F - 24°C" seems to be the ideal temperatures during the day and no lower than about 55°F (13°C) during the night.'},
#  {'origin': 'Central and South America.',
#   'Common Name': 'Flamingo flower, pigtail plant ',
#   'scientific_name': '. -- Anthurium scherzerianum ',
#   'Max_Growth': '12 - 18 inches in height.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/flamingo-flower-plant.jpg',
#   'temperature': "Average room temperatures from 65°F/18.3°C - 75°F/23.8°C (maybe a little higher and not below 60°F/15.5°C). Lower temperatures will affect it's leaves (may turn yellow), impede it's growth and flowering."},
#  {'origin': 'South America.',
#   'Common Name': 'Flaming Sword ',
#   'scientific_name': '. Vriesea splendens ',
#   'Max_Growth': 'Height 18 in/45 cm, diameter 10 in/25 cm.',
#   'Poisonous_for_pets': 'Non-Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/flaming-sword-plant.jpg',
#   'temperature': 'Temperature:To bring them in to flower you may need to keep the temperature up to around 75°f / 24°c and then average room temperatures above 65°f / 18.3°c at any other time.'},
#  {'origin': 'South America.',
#   'Common Name': 'F. maple, ',
#   'scientific_name': '. -- Abutilon hybridum ',
#   'Max_Growth': 'Height 5 ft or more. ',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/abutilon-hybridum.jpg',
#   'temperature': 'They thrive in summer conditions and prefer temperature’s from 60°F-15.5°C/ 80°F-26.6°C . Avoid lower than 50°F/10°C in the winter.'},
#  {'origin': 'South Africa.',
#   'Common Name': 'Kaffir and bush lily ',
#   'scientific_name': '-- Clivia miniata ',
#   'Max_Growth': '18 inches in height.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/Clivia-Miniata.jpg',
#   'temperature': 'Temperatures from cool to average room 60°F/15.5°C - 75°F/23.8°C are best suited.\nThe resting period needed within the winter needs the temperature to be much cooler - at 40°F/4.5°C - 50°F/10°C.'},
#  {'origin': 'Central and South America.',
#   'Common Name': 'Lollipop and golden shrimp plant ',
#   'scientific_name': '. Pachystachys Lutea ',
#   'Max_Growth': 'Height 1 - 2ft indoors, outdoors 4ft. Spread 2 - 3ft.',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/pachystachys-lutea-flowers.jpg',
#   'temperature': 'Average room temperatures of around 65°f / 16°c --- 75°f are ideal, and no lower that 55°f 12.7°c, during winter. You can allow the plant some time outdoors during summer, not in direct sun.'},
#  {'origin': 'Madagascar.',
#   'Common Name': 'Madagascar Jasmine - Wax Flower ',
#   'scientific_name': '. -- Stephanotis Floribunda ',
#   'Max_Growth': '10ft tall and more.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/madagascar_jasmine.jpg',
#   'temperature': 'Temperatures from 65 - 80°F (18 - 26°C) are ideal during spring and summer. Try around 55 - 60°F (13 - 15°C) for a month or two during winter (before spring) but no lower than 45°F (7°C) which may encourage blooms for late spring - summer.'},
#  {'origin': 'Central America, Mexico.',
#   'Common Name': 'Medusa Plant ',
#   'scientific_name': '. -- Tillandsia Caput Medusae ',
#   'Max_Growth': 'Height 6in (15cm). ',
#   'Poisonous_for_pets': 'Not known..',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/medusas-head-plant.jpg',
#   'temperature': 'Average to high temperatures help the Caput Medusae to flower, from 65° - 86°F (18°- 30 °C). Keep the minimum no lower than 55°F (°12C) indoors or outside. '},
#  {'origin': 'South America.',
#   'Common Name': 'Christmas and ornamental pepper plant ',
#   'scientific_name': '. -- Capiscum annuum ',
#   'Max_Growth': '1½ ft tall.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/ornamental_pepper_close_up.jpg',
#   'temperature': 'Cool temperatures from 55°F/13°C - 65°F/18°C are ideal during the night and 70°F/21°C - 80°F/26°C, during the day. Avoid lower than 55°F/13°C.'},
#  {'origin': 'Mexico and Central America.',
#   'Common Name': 'Poinsettia, ',
#   'scientific_name': '. Euphorbia Pulcherrima ',
#   'Max_Growth': 'Height 18" (45cm).',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/Poinsettia-bract.jpg',
#   'temperature': 'Average temperatures from 65 - 75°F (18 - 24°C) and no less than 55°F (13°C) are fine during the flowering season. Follow the guidelines above on re-flowering after March.'},
#  {'origin': 'South America .',
#   'Common Name': 'Queens tears, friendship plant ',
#   'scientific_name': '. Billbergia nutans ',
#   'Max_Growth': 'Height 18 in/45 cm.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/queens_tears_flower_head.jpg',
#   'temperature': "This plant is picky about the temperature that it likes to live at. Depending on the season,\nyour plant will demand different temperatures in order to maintain its health. In the summer,\noffer the plant a spot that is 65-80ºF (18-27ºC). In the fall, winter, and cooler spring months,\nthe plant needs a 60-75ºF (16-24ºC) temperature. During the coldest winter, occasional periods can be\nwithstood up to 40ºF (4ºC), but extended exposure will affect the coming year's bloom."},
#  {'origin': 'China.',
#   'Common Name': 'Rose of China, Chinese hibiscus, Shoe flower ',
#   'scientific_name': '. Hibiscus Rosa-Sinensis ',
#   'Max_Growth': 'Height 18 ft - Leaves 3 in long - Flowers 4-5 inches.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/rose-of-china-flower.jpg',
#   'temperature': 'Minimum temperature should be no lower than 55°F (10°C). Ideal is approximately 60° - 75°F (15° - 24°C).'},
#  {'origin': 'Central and South America.',
#   'Common Name': 'Scarlet star ',
#   'scientific_name': '. Guzmania lingulata ',
#   'Max_Growth': 'Height 18 in/45 cm.',
#   'Poisonous_for_pets': 'Non toxic for cats, dogs',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/scarlet-star-bromeliad.jpg',
#   'temperature': 'The Scarlet Star prefers an average temperature of 65-80°F (18-27°C). When kept in this temperature, the plant will continue to grow all year long.'},
#  {'origin': 'Southeast Asia.',
#   'Common Name': "The one colored paphiopedilum, lady's slipper ",
#   'scientific_name': '. P. concolor ',
#   'Max_Growth': 'Height 6" max.',
#   'Poisonous_for_pets': 'Not confirmed.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/the-one-colored-paphiopedilum.jpg',
#   'temperature': "In their native countries the one colored paphiopedilum thrives in quite humid conditions which makes temperatures between 70-80°F (21-27°C) ideal without direct sun light. Temperatures will naturally drop during the night (and in winter), but do not allow them to drop lower than 50°F (10°C). Try and keep your plant away from cold drafts. In some climates it's fine to give your paphiopedilum time outside, although in more northern territories I would advise against this because of the extreme changes in temperatures and rainfall (which can be fairly cold)."},
#  {'origin': 'Brazil.',
#   'Common Name': 'Urn and pink or silver vase plant ',
#   'scientific_name': '. Aechmea Fasciata ',
#   'Max_Growth': 'Height 18 in/45.7 cm, diameter 26 in/66 cm.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/Aechmea-Fasciata.jpg',
#   'temperature': 'Average room temperatures between 65°F (18.3°C) - 75°F (24°C) are suitable and maintain temperatures around the 75°F (24°C) mark to bring flowers in to bloom.'},
#  {'origin': 'Peru and Ecuador.',
#   'Common Name': 'Winter cherry ',
#   'scientific_name': '. Solanum capsicastrum ',
#   'Max_Growth': 'Height 24 in (60 cm).',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/solanum-capiscastrum-leaves.png',
#   'temperature': 'The winter cherry prefers cool temperatures of approximately 60-70°F (15-21°C) and 50-60°F (10-15°C) during winter. Avoid placing the plant near cold drafts.'},
#  {'origin': 'North Africa.',
#   'Common Name': 'Aluminum Plant ',
#   'scientific_name': '. Pilea Cadierei ',
#   'Max_Growth': 'Height 1 - 2 ft .',
#   'Poisonous_for_pets': 'Toxic for cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/aluminum_plant.jpg',
#   'temperature': 'Pilea cadierei requires a year-round temperature between 60-75 ºF (15-23 ºC). It can tolerate short periods of time outside of this temperature range, but continued exposure will kill the plant.'},
#  {'origin': 'Madagascar.',
#   'Common Name': 'Areca, butterfly, or cane palm ',
#   'scientific_name': '. Dypsis lutescens [syn.] Chrysalidocarpus or areca lutescens ',
#   'Max_Growth': 'Height 8ft.',
#   'Poisonous_for_pets': 'Non toxic for cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/images/areca_palm22.jpg',
#   'temperature': 'Average room temperatures of 65°F (16°C) --- 75°F (24°C) are suitable and no lower than 55°F (12.7°C).\nSudden cold temperature drops and cold drafts can cause the leaves to display brown spots.'},
#  {'origin': 'South America.',
#   'Common Name': 'Arrowhead Plant or Arrowhead Vine, Goosefoot Plant ',
#   'scientific_name': '. Syngonium Podophyllum, also named Nephthytis Podophyllum ',
#   'Max_Growth': 'Height 6ft indoors (much higher outdoors when climbing). ',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/arrowhead_plant.jpg',
#   'temperature': ' Temperatures of at least 60-85 ºF (15-29 ºC) need to be maintained year round. This species may cope with 50 ºF (10 ºC). Anything lower can kill off your plant.'},
#  {'origin': 'South East Asia and East Australia.',
#   'Common Name': "Bird's Nest Fern ",
#   'scientific_name': '. -- Asplenium Nidus ',
#   'Max_Growth': 'Height 2ft.',
#   'Poisonous_for_pets': 'Non toxic for cats, dogs',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/asplenium_nidus_attached_to_tree_1.jpg',
#   'temperature': 'Room temperatures between 65-75ºF (18-24ºC) are ideal, and no lower than 55ºF (13ºC).'},
#  {'origin': 'America.',
#   'Common Name': 'Boston Fern ',
#   'scientific_name': ". -- Nephrolepis Exaltata 'Bostoniensis' ",
#   'Max_Growth': 'Fronds, length and height approx 3ft max. ',
#   'Poisonous_for_pets': 'Non toxic for cats, dogs',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/boston_ferns_in_hanging_baskets_1.jpg',
#   'temperature': 'The ideal room temperatures for Boston ferns is between 60-75ºF (16-24ºC). No lower than 55ºF (13ºC). Avoid warm air from indoor heating and cold drafts.'},
#  {'origin': 'China and Taiwan.',
#   'Common Name': 'Broadleaf lady or little lady palm ',
#   'scientific_name': '. Rhapis excelsa ',
#   'Max_Growth': 'Height 14 feet (4 meters). Must be pruned to keep the tree at a manageable size indoors.',
#   'Poisonous_for_pets': 'Non toxic for cats, dogs',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/broadleaf_lady_palm1.jpg',
#   'temperature': 'It is almost impossible to upset the temperature of the Broadleaf Lady Palm. It will happily tolerate temperatures from 20-100°F (-6-37°C), and can survive short stays outside of this temperature zone.'},
#  {'origin': 'Canary Islands.',
#   'Common Name': 'Canary Island Date Palm ',
#   'scientific_name': '. Phoenix Canariensis ',
#   'Max_Growth': 'Height 6ft indoors.',
#   'Poisonous_for_pets': 'Non toxic for cats, dogs',
#   'big_image_url': 'https://www.houseplantsexpert.com/images/canary.jpg',
#   'temperature': 'Happily tolerate temperatures from 20-100°F (-6-37°C), and can survive short stays outside of this temperature zone.'},
#  {'origin': 'Japan & Taiwan.',
#   'Common Name': 'Cast iron plant ',
#   'scientific_name': '. Aspidistra elatior ',
#   'Max_Growth': 'Height 36 in (91 cm).',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/cast-iron-plant.jpg',
#   'temperature': 'Average warmth is fine of approximately 60-75°F (15-24°C) and no lower than 45°F (8°C). They will tolerate much lower temperatures.'},
#  {'origin': 'Tropics and subtropics of Asia.',
#   'Common Name': 'Chinese evergreen ',
#   'scientific_name': '. -- A. commutatum, A modestum, A pictum and others. ',
#   'Max_Growth': 'Height 3ft. ',
#   'Poisonous_for_pets': 'Toxic to cats, dogs and horses.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/chinese_evergreen1.png',
#   'temperature': 'Temperatures between 65-80 ºF (18-27 ºC) are ideal. Lower than 60ºF (15ºC) is not healthy for this plant and can cause dark patches on the leaves. If the leaves begin to curl and the edges turn brown the temperature is probably too low or cold drafts may be affecting the plant.'},
#  {'origin': 'Various pacific ocean areas.',
#   'Common Name': 'Coral bead, pin cushion plant ',
#   'scientific_name': '. Nertera granadensis ',
#   'Max_Growth': 'Height 5 in/13 cm, diameter depends on pot size and plant maturity.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/coral-bead-plant.jpg',
#   'temperature': "Nertera granadensis prefers temperatures on the cooler side. The plant should remain at 55-65ºF (13-18ºC) all year round. Occasional temperature spikes as high as 80ºF (26ºC) and low as 40ºF (4ºC) are tolerated, but must be remedied within a week for the plant's health. Temperatures above 65ºF (18ºC) during flowering will result in no berries produced during that season."},
#  {'origin': 'Africa.',
#   'Common Name': 'Corn or cornstalk plant ',
#   'scientific_name': '. -- Dracaena fragrans ',
#   'Max_Growth': 'Height 6ft and more indoors. ',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/dracaena_fragrans.jpg',
#   'temperature': 'Temperatures from 60°F (15°C) - 75°F (24°C) are ideal. Under 55°F/12°C is going to harm the plant which may become noticeable if the leaves begin curling. Try and avoid the plant being near cold drafts, which will also cause harm.'},
#  {'origin': 'East Asia.',
#   'Common Name': 'Creeping or climbing fig ',
#   'scientific_name': '. -- Ficus pumila, [syn.] ficus repens ',
#   'Max_Growth': 'No maximum spread and only a few inches high. ',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/creeping_fig.jpg',
#   'temperature': 'The pumila is a tough plant and grows well in temperatures from 55 - 75°F (13 - 24°C (can be higher or lower and survive). '},
#  {'origin': 'Europe, Asia and Africa.',
#   'Common Name': 'Cretan Brake Fern ',
#   'scientific_name': '. -- Pteris Cretica ',
#   'Max_Growth': 'Height 1 - 2.5ft. ',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/images/cretan_brake.jpg',
#   'temperature': 'The ideal temperature to provide is between 65-75ºF (18-24ºC) for this plant. The minimum is 55ºF (13ºC).'},
#  {'origin': 'South India, Sri Lanka, Malaysia, Western Pacific Islands.',
#   'Common Name': "Croton, Joseph's coat ",
#   'scientific_name': '. -- Codiaeum variegatum, [syn.] Croton variegatum ',
#   'Max_Growth': 'Height 3 ft.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/Codiaeum_Variegatum.png',
#   'temperature': 'Temperatures between 65-80ºF (18-27ºC) are ideal, and no lower than 60ºF (15ºC). Avoid cold drafts from near windows and doors.'},
#  {'origin': 'West Indies.',
#   'Common Name': 'Dumb cane ',
#   'scientific_name': '. -- Dieffenbachia Amoena ',
#   'Max_Growth': 'Height 6ft.',
#   'Poisonous_for_pets': 'Seriously toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/dumb_cane_plant.jpg',
#   'temperature': 'Dieffenbachia amoena grows best when the temperature it is exposed to is between 65-75 ºF (18-23 ºC). Outside of this temperature zone, growth will continue at a greatly reduced rate, with tolerance extremes ranging from 40-90 ºF (4-35 ºC) Beyond these extremes, the plant will stop growing and may die with prolonged exposure.'},
#  {'origin': 'Southeast Asia.',
#   'Common Name': "Elephant's ear - Alocasia polly - African mask",
#   'scientific_name': '. Alocasia Amazonica ',
#   'Max_Growth': 'Height 1 - 2 ft .',
#   'Poisonous_for_pets': 'Toxic for cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/elephants_ear_plant.jpg',
#   'temperature': 'Told you that you was going to need to keep this plant warm. Ideal temperatures should be approximately 65-75ºF + (18-24ºC +)...closer to 70ºF is best.'},
#  {'origin': 'Southern Europe.',
#   'Common Name': 'European fan, Mediterranean dwarf palm, and Dwarf fan palm ',
#   'scientific_name': '. Chamaerops humilis ',
#   'Max_Growth': '4ft tall and 3ft spread, small tree (much more outdoors).',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/european-fan.jpg',
#   'temperature': 'Average room temperatures are fine. This a cold hardy palm and will not have a problem in temperatures as low as 40ºF (4ºC).'},
#  {'origin': 'Western Africa.',
#   'Common Name': 'Fiddle leaf fig tree ',
#   'scientific_name': '. -- Ficus lyrata, [syn.] Ficus pandurata ',
#   'Max_Growth': 'Height 10ft (3m). ',
#   'Poisonous_for_pets': 'Toxic to cats, dogs and horses.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/ficus_lyrata2.png',
#   'temperature': 'Temperature:Temperatures between 60 - 75°F (15 - 24°C are suitable. Avoid lower than 55°F (12°C).'},
#  {'origin': 'Australia, Indonesia, China, Japan and India.',
#   'Common Name': 'Golden pothos or Devils ivy ',
#   'scientific_name': '. -- Epipremnum aureum ',
#   'Max_Growth': 'Height 6ft. ',
#   'Poisonous_for_pets': 'Toxic to cats, dogs and horses.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/golden_pothos1.jpg',
#   'temperature': 'To keep this plant as healthy as possible, keep it at temperatures between 60-85 ºF (15-29 ºC) year round. It will withstand occasional cold snaps down to 50 ºF (10 ºC), but below this, the plant will die.'},
#  {'origin': 'Southeast Asia.',
#   'Common Name': 'Green Velvet Alocasia, Alocasia Frydek ',
#   'scientific_name': ". Alocasia Micholitziana 'Frydek' ",
#   'Max_Growth': 'Height 2 - 3ft .',
#   'Poisonous_for_pets': 'Toxic for cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/alocasia_micholitziana_frydek1.jpg',
#   'temperature': 'The best temperature for this plant is approximately 65-75ºF + (18-24ºC +) or more.'},
#  {'origin': 'Southeast Asia and Western Pacific Ocean Areas.',
#   'Common Name': 'Hawaiian ti, good luck, baby doll ti and others ',
#   'scientific_name': '. -- Cordyline fruticosa , [syn.] C. terminalis ',
#   'Max_Growth': 'Height 3 - 4ft indoors. ',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/green_leafed_cordiline_fruticosa1.jpg',
#   'temperature': 'Temperatures between 65-80ºF (18-27ºC) are ideal, and no lower than 60ºF (15ºC). Avoid cold drafts from near windows and doors.'},
#  {'origin': 'South America.',
#   'Common Name': 'Heart of Jesus, angel wings, elephant ear, fancy leafed caladium ',
#   'scientific_name': '. Caladium bicolor or Caladium hortulanum and others. ',
#   'Max_Growth': 'Height 25in (60cm).',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/caladium1.jpg',
#   'temperature': 'Above 70ºF (21ºC) is the best temperature to provide, and no lower than 60ºF (15ºC).'},
#  {'origin': 'Lord Howe Island (Australia - New South Wales State).',
#   'Common Name': 'Kentia, paradise, thatch ',
#   'scientific_name': '. Howea forsteriana ',
#   'Max_Growth': 'Height 10ft.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/kentia-palm-houseplant.jpg',
#   'temperature': 'Room temperatures of around 65°f / 16°c --- 75°f / 24°c are ideal.\nThe temperature should not become lower than 55°f / 12.7°c.'},
#  {'origin': 'Africa.',
#   'Common Name': 'Lucky Bamboo ',
#   'scientific_name': '. -- Dracaena Braunii, or Dracaena Sanderiana ',
#   'Max_Growth': 'Height 3ft. ',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/lucky-bamboo.jpg',
#   'temperature': " Warm room temperature's and above are advised 65°F (18°C) - 90°F (32°C). Avoid lower than 55°F/12°C in the winter."},
#  {'origin': 'Madagascar.',
#   'Common Name': 'Dragon Tree ',
#   'scientific_name': '. Dracaena marginata ',
#   'Max_Growth': 'Height 8ft. ',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/Dracaena-marginata.jpg',
#   'temperature': 'Average room temperatures are ideal between 65°- 75°F (18°- 24 °C) or more. They will live through much colder temperatures during winter (as I have observed), but keeping them in optimal health requires the room to be no less than 50°F (10°C).'},
#  {'origin': 'South America.',
#   'Common Name': 'Delta Maidenhair Nest Fern ',
#   'scientific_name': '. -- Adiantum Raddianum ',
#   'Max_Growth': 'Height 1.5ft. ',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/maidenhairfern.jpg',
#   'temperature': 'The ideal temperature to provide is between 65-75ºF (18-24ºC) for this plant. The minimum is 55ºF (13ºC).'},
#  {'origin': 'South and Central America.',
#   'Common Name': 'Mexican fortune tree, money tree plant and others ',
#   'scientific_name': '. -- Pachira Aquatica ',
#   'Max_Growth': '10ft tall.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/pachira_money_tree.jpg',
#   'temperature': 'Room temperatures from 65-75ºF (18-24ºC) are suitable, and no lower than 50ºF (10ºC).'},
#  {'origin': 'Mexico.',
#   'Common Name': 'Parlor, Parlour palm ',
#   'scientific_name': '. Chamaedorea elegans ',
#   'Max_Growth': 'Height 4 ft.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/parlor-palm.jpg',
#   'temperature': 'Average warmth 65°F (18°C) and above is fine and no less than 50°F (10°C) at night.'},
#  {'origin': 'South-East-Asia.',
#   'Common Name': 'Pygmy date, Miniature date palm ',
#   'scientific_name': '. Phoenix roebelenii ',
#   'Max_Growth': 'Height 6ft.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/pygmy-date.JPG',
#   'temperature': 'Room temperatures of around 65°f / 16°c --- 75°f / 24°c are ideal.\nThe temperature should not become lower than 50°f / 10°c during winter.'},
#  {'origin': 'Fiji.',
#   'Common Name': "Rabbit's Foot Fern ",
#   'scientific_name': '. Davallia Fejeensis ',
#   'Max_Growth': 'Height 1 - 2ft. ',
#   'Poisonous_for_pets': 'Non toxic for cats, dogs and horses.',
#   'big_image_url': 'https://www.houseplantsexpert.com/images/rabbits_foot_fern.jpg',
#   'temperature': 'Temperatures from 60-75ºF (15-24ºC) is advised. No lower than 55ºF (13ºC).'},
#  {'origin': 'Brazil.',
#   'Common Name': 'Rattlesnake Plant ',
#   'scientific_name': '. Calathea Lancifolia and C. Insignis.',
#   'Max_Growth': ' 30" tall.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/calathea_lancifolia.jpg',
#   'temperature': 'Room temperatures that average 65-75ºF (18-24ºC) and no lower than 60ºF (15ºC). Avoid drafts and sudden temperature changes.'},
#  {'origin': 'Brazil. ',
#   'Common Name': 'Rose Painted Calathea ',
#   'scientific_name': '. Calathea Roseopicta ',
#   'Max_Growth': 'Height 20in (50cm) or more. ',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/images/calathea_roseopicta_leaf.jpg',
#   'temperature': 'Average room temperatures of 65-75ºF (18-24ºC) are suitable, and no lower than 60ºF (15ºC).\nSudden temperature drops and cold drafts should be avoided.'},
#  {'origin': 'India, Nepal, Myanmar, China, Malaysia & others.',
#   'Common Name': 'Rubber plant or tree, rubber bush ',
#   'scientific_name': '. Ficus elastica ',
#   'Max_Growth': 'Height 10ft (3m). ',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/rubber_plant.jpg',
#   'temperature': 'Average room temperatures of 60 - 75°F (15 - 24°C are fine. Avoid lower than 55°F (12°C), sudden temperature drops and cold drafts.'},
#  {'origin': 'Asia.',
#   'Common Name': 'Sago Palm ',
#   'scientific_name': '. Cycas Revoluta ',
#   'Max_Growth': 'Height 2ft indoors.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs (see article).',
#   'big_image_url': 'https://www.houseplantsexpert.com/images/sago_palm.jpg',
#   'temperature': 'Temperature: Average room temperatures of 65°F (16°C) --- 75°F (24°C) are suitable and\nno lower than 55°F (12.7°C). '},
#  {'origin': 'Lord Howe Island (Australia - New South Wales State)',
#   'Common Name': 'Sentry, belmore sentry, and curly palm ',
#   'scientific_name': '. Howea belmoreana ',
#   'Max_Growth': 'Height 10ft (much more in the wild). ',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/sentrypalm-plant.jpg',
#   'temperature': 'Room temperatures of around 65°f / 16°c --- 75°f / 24°c are ideal.\nThe temperature should not decline lower than 55°f / 12.7°c.'},
#  {'origin': 'Madagascar and other Indian ocean islands.',
#   'Common Name': 'Song of India, Pleomele ',
#   'scientific_name': '. Dracaena Reflexa ',
#   'Max_Growth': 'Height 3ft and more indoors. ',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/dracaena_reflexa.png',
#   'temperature': 'The ideal temperatures are between 60°F (15°C) - 80°F (27°C). Allowing temperatures to go below 55°F/12°C can harm the plant. Avoid having a plant sitting near cold drafts.'},
#  {'origin': 'South Africa.',
#   'Common Name': 'Spider or airplane ',
#   'scientific_name': '. Chlorophytum comosum vittatum and variegatum ',
#   'Max_Growth': 'Height 60 cm - leaves 45 cm.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/spiderplant_2.jpg',
#   'temperature': ' Minimum temperature should be no lower than 45°F (7°C). Ideal is approximately 60° - 75°F (15° - 24°C).'},
#  {'origin': 'South Mexico to Columbia.',
#   'Common Name': 'Swiss cheese or just cheese plant ',
#   'scientific_name': '. -- Monstera Deliciosa ',
#   'Max_Growth': 'Height over 10 ft tall.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/swiss_cheese_plant_flower.jpg',
#   'temperature': 'Temperatures between 65-80ºF (18-27ºC) are ideal. Lower than 65ºF (18Cº) will slow down this plants growth and below 50ºF (10ºC) will stop growth.'},
#  {'origin': 'Taiwan.',
#   'Common Name': 'Umbrella Plant, Queensland Umbrella Tree, Octupus Tree, Gold Capella ',
#   'scientific_name': '. Schefflera Arboricolum, Syn. Heptapleurum Arboricolum ',
#   'Max_Growth': 'Height 10ft tall or more. ',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/umbrella_plant.jpg',
#   'temperature': 'Grows well in average room temperatures between 60 - 75 °F (15 - 24°C) but no lower than 55F (13C) or higher than 75°F (24°C). Avoid sudden temperature drops and cold drafts.'},
#  {'origin': 'North and South Carolina.',
#   'Common Name': 'Venus fly trap ',
#   'scientific_name': '. -- Dionaea Muscipula ',
#   'Max_Growth': '3 - 10 cm long stems.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/venus-fly-trap.jpg',
#   'temperature': 'These plants are happiest between 60°- 90°F (15°- 32°C) for most of the year. During the winter months, they enter a dormancy period, and can withstand temperatures as low as 30°F (-1°C) for short periods of time.'},
#  {'origin': 'South America.',
#   'Common Name': 'Wandering Jew, Flowering Inch Plant ',
#   'scientific_name': '. Tradescantia Zebrina, Tradescantia Fluminensis [Syn. T. Albiflora] -- ',
#   'Max_Growth': 'Stems grow over 2ft long.',
#   'Poisonous_for_pets': 'Non-toxic to cats and toxic to dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/images/wandering_jew2.jpg',
#   'temperature': 'Average indoor temperatures of 65-75ºF (18-24ºC) are suitable, and no lower than 50ºF (10ºC).'},
#  {'origin': 'South East Asia and Australia.',
#   'Common Name': 'Weeping Fig ',
#   'scientific_name': '. Ficus Benjamina ',
#   'Max_Growth': 'Height up-to 10ft and miniature grown types 3ft.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/ficus-benjamina.jpg',
#   'temperature': 'Room temperatures of around 65°f / 16°c --- 75°f / 24°c is ideal.\nTry not to allow temperatures to decrease lower than 50°f / 10°c, although they can handle a bit lower, without problems.'},
#  {'origin': 'Brazil.',
#   'Common Name': 'Zebra plant ',
#   'scientific_name': '. Aphelandra squarrosa ',
#   'Max_Growth': 'Height 2ft. ',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/zebra_plant_1.png',
#   'temperature': 'Temperatures from 60-75 ºF (15-23 ºC) are ideal and no lower than 55 ºF (13 ºC).'},
#  {'origin': 'Mexico.',
#   'Common Name': 'Zebra plant ',
#   'scientific_name': '. Calathea zebrina ',
#   'Max_Growth': 'Height 1m. ',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/images/zebrina.jpg',
#   'temperature': 'Average room temperatures of 65-75ºF (18-24ºC) are best, and no lower than 60ºF (15ºC). Sudden temperature drops and cold drafts should be avoided.'},
#  {'origin': 'Africa ',
#   'Common Name': 'ZZ plant ',
#   'scientific_name': '. Zamioculcas zamiifolia ',
#   'Max_Growth': 'Stems length 3ft (30 cm). ',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/zz_plant.png',
#   'temperature': 'Average warmth is fine of approximately 60-75°F (15-24°C) and no lower than 45°F (8°C).'},
#  {'origin': 'North Africa.',
#   'Common Name': 'Aloe V, Medicine Plant, True Aloe, Burn Plant, ',
#   'scientific_name': '. -- Aloe V, Aloe barbadensis ',
#   'Max_Growth': 'Height 1 - 2 ft .',
#   'Poisonous_for_pets': 'Toxic for cats and dogs.',
#   'big_image_url': 'assets/images/aloe-plant-near-window-1.jpg',
#   'temperature': 'Temperatures averaging 70°F/21°C - 80°F/26°C are very good and not much below 50°F/10°C.'},
#  {'origin': 'Africa',
#   'Common Name': 'Not known ',
#   'scientific_name': '. Argyroderma testiculare ',
#   'Max_Growth': 'Height 5cm - 15cm max.',
#   'Poisonous_for_pets': "Not known, but it's unlikely a pet will chew on this type of foliage, although they could be curious and might want to plan with them..",
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/argyroderma_testiculare.jpg',
#   'temperature': 'Due to where the Argyroderma testiculare originated from it can comfortably handle temperatures of up to 85°F (30°C), however, it is not frost resistant and will need to be protected from cold weather (Min 50°F - 10°C) .\n'},
#  {'origin': 'South America.',
#   'Common Name': 'Baby rubber plant, American rubber plant, Pepper face plant ',
#   'scientific_name': '. Peperomia obtusifolia ',
#   'Max_Growth': '25 - 30 cm tall.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/american_baby_rubber_plant.jpg',
#   'temperature': 'Ideal temperatures of 65-75ºF (18-24ºC), and no lower than 50ºF (10ºC).'},
#  {'origin': 'Mexico.',
#   'Common Name': 'Bunny ear and polka-dot cactus ',
#   'scientific_name': '. Opuntia Microdasys ',
#   'Max_Growth': 'Height 12 - 18in/30.5 - 45.5cm.',
#   'Poisonous_for_pets': 'The fruit and flowers are non-toxic to pets, but the glochids are moderately irritating to the skin.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/close-up-of-glochids-opuntia-microdasys.jpg',
#   'temperature': 'This cactus enjoys temperatures ranging from 70-100°F (21-37°C), but demands cooler temperatures during the winter months.\nStarting in the late fall, this cactus should be kept between 50-65°F (10-18°C), and away from central heating vents. The cooler spell is\ndemanded over the course of the entire winter, during which time the segments of cactus will turn a light gray color. Failure to provide\nthese controlled winter conditions will result in plant death the following spring.'},
#  {'origin': 'South America.',
#   'Common Name': 'Century plant, Agave cactus, Maguey, American aloe ',
#   'scientific_name': '. Agave americana ',
#   'Max_Growth': 'Height 1m - 1.5m.',
#   'Poisonous_for_pets': 'Toxic for cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/century_plant.jpg',
#   'temperature': 'The plant thrives in warm temperatures during the summer although the winter months can prove troublesome should the temperature fall below 10°C. It handles changes in day and night time temperatures very well. Temperatures averaging 70°F/21°C - 80°F/26°C are very good and not much below 50°F/10°C. '},
#  {'origin': 'Brazil.',
#   'Common Name': 'Christmas and holiday cactus ',
#   'scientific_name': '. Schlumbergera Bridgesii, S. × buckleyi',
#   'Max_Growth': 'Height 10 in/25.4 cm, diameter 24 in/61 cm.',
#   'Poisonous_for_pets': 'Non-Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/christmas-cactus.jpg',
#   'temperature': 'This cactus requires a resting period that helps it to bloom again, from Feb - March. During this time keep temperatures at approximately 55°F (12.7°C) and water less. Pre - flowering period from Oct - Nov requires the plant soil to be kept fairly dry until flowers bud, and then resume normal watering and temperatures.'},
#  {'origin': ' Mexico',
#   'Common Name': 'Christmas cheer, Pork and beans ',
#   'scientific_name': '. Sedum rubrotinctum ',
#   'Max_Growth': 'Height upto 1 ft (30 cm).',
#   'Poisonous_for_pets': 'Mildly toxic for cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/sedum_rubrotinctum.jpg',
#   'temperature': 'It is more suited to hotter climates and this means that temperatures below freezing will damage the plants. Moving the plant indoors during cold snaps will help to maintain its growth and health, especially if placed on a windowsill that is western or southern facing. N\nNo lower than 50 °F (10°F) - 55°F (12.7°C) is best and during summer between 65°F (18°C) - 75°F - (23.8°C+).\n'},
#  {'origin': 'Africa and then developed in Thailand to the Lactea crest.',
#   'Common Name': 'Coral cactus ',
#   'scientific_name': '. Eurphorbia lactea crest ',
#   'Max_Growth': 'Height 9 in - 15 in.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs (see description).',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/coral-cactus-orig.jpg',
#   'temperature': "The Coral likes it's sunshine and warm conditions which help it to grow and maintain's it's health.\nA partially sunny spot and average temperatures of no lower than approximately 60°F (15°C) will suffice."},
#  {'origin': 'South Mexico.',
#   'Common Name': "Donkey's and Burros Tail ",
#   'scientific_name': '. Sedum Morganianum ',
#   'Max_Growth': 'Stems trail from 1 - 3 ft long .',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/donkeys_tail_sedum.jpg',
#   'temperature': 'Temperatures averaging 65°F/18°C - 80°F/26°C are very good and not much below 50°F/10°C. During winter it is fine if the temperature drops down and it can encourage them to actually bloom in the forthcoming spring season.'},
#  {'origin': 'Brazil.',
#   'Common Name': 'Easter or holiday cactus ',
#   'scientific_name': '. Hatiora Gaertneri ',
#   'Max_Growth': 'Height 25 in/63 cm.',
#   'Poisonous_for_pets': 'Non-Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/Hatiora-gaertneri.jpg',
#   'temperature': 'Temperature: The tropical Hatiora gaertneri prefers spring, summer, and fall temperatures around 75-80°F (24-27°C). Winter temperatures should be between 45-6°5F (7-18°C) only.'},
#  {'origin': 'Canary Islands.',
#   'Common Name': 'Housetree Leek, Black Rose Tree ',
#   'scientific_name': '. Aeonium Arboreum - var. Atropurpureum and Zwartkop/Schwarzkopf ',
#   'Max_Growth': 'Max 3ft tall.',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/aeonium_arboreum_zwartkop.jpg',
#   'temperature': 'Temperatures averaging 70°F/21°C - 85°F/29.4°C. Avoid below 50°F/10°C. During summer this species will appreciate being taken outside and then brought back in when colder weather sets in.'},
#  {'origin': 'Madagascar.',
#   'Common Name': 'Flaming katy ',
#   'scientific_name': '. -- Kalanchoe blossfeldiana ',
#   'Max_Growth': '18 inches in height.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/flaming-katy-plants-potted.jpg',
#   'temperature': 'Average room temperatures from 65°F/18.3°C - 75°F/23.8°C and no lower than 50°F/10°C, is best; avoiding frost if they are grown or sitting outside for a period of time.'},
#  {'origin': 'North Mexico.',
#   'Common Name': "Goat's horn cactus ",
#   'scientific_name': '. Astrophytum Capricorne ',
#   'Max_Growth': 'Height 18 in/45 cm, diameter 10 in/25 cm.',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/goats-horn-cactus-flowering.jpg',
#   'temperature': 'Average temperatures between 60-80°F (15-21°C) from spring until fall, and between 50-55°F (10-12°C) during winter. '},
#  {'origin': 'Mexico.',
#   'Common Name': "Golden barrel cactus , golden ball cactus, mother-in-law's cushion ",
#   'scientific_name': '. -- Echinocactus Grusonii ',
#   'Max_Growth': 'Height 60in (24cm). Diameter 36in (91cm).',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/Golden_Barrel_Cactus.jpg',
#   'temperature': 'Temperatures averaging 50°F/10°C - 75°F/23.8°C are ideal but not below 40°F/5°C and avoid frost.'},
#  {'origin': 'South Africa.',
#   'Common Name': 'Jade, money , lucky, friendship ',
#   'scientific_name': '. Crassula Ovata, C.portulacea, C.argentea ',
#   'Max_Growth': 'Height = 3ft or much less, as a bonsai.',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/jade-plant.jpg',
#   'temperature': 'Room temperatures of around 60°f / 15.5°c --- 75°f / 24°c are ideal. Winter no less than 50°f / 10°c.'},
#  {'origin': ' Mexico',
#   'Common Name': 'Jelly beans, Many fingers ',
#   'scientific_name': '. Sedum pachyphyllum ',
#   'Max_Growth': 'Height upto 1 ft (30 cm).',
#   'Poisonous_for_pets': 'Mildly toxic for cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/jelly_beans_plant.jpg',
#   'temperature': 'Cool temperatures in the winter no lower than 50 °F (10°F) - 55°F (12.7°C) is best and during summer between 65°F (18°C) - 75°F - (23.8°C+).\nThe Sedum Pachyphyllum does tend to grow well in hotter conditions but it is important to remember that it should not be kept outside when the temperature drops to freezing. It should then be moved indoors and should be positioned by a western or southern facing window.'},
#  {'origin': 'Western Africa.',
#   'Common Name': "Mother in law's tongue and snake plant ",
#   'scientific_name': '. Sansevieria trifasciata ',
#   'Max_Growth': 'Height 30 in (70 cm).',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/mother-in-laws-tongue-plant.jpg',
#   'temperature': 'Average warmth is fine of approximately 60-75°F (15-24°C) and no lower than 50°F (10°C).'},
#  {'origin': 'South Mexico.',
#   'Common Name': 'Orchid Cactus ',
#   'scientific_name': '. Disocactus Ackermannii ',
#   'Max_Growth': '4 feet wide, if not pruned.',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/Disocactus-Ackermannii.jpg',
#   'temperature': 'Keep this cactus between 60-75ºF (16-24ºC) during its active cycle.\nDuring the resting period, daytime temperatures must be 60-65ºF (16-18ºC) and night-time temperatures must be 40-55ºF (4-12ºC).'},
#  {'origin': 'Madagascar.',
#   'Common Name': 'Panda plant or pussy ears ',
#   'scientific_name': '. Kalanchoe tomentosa ',
#   'Max_Growth': 'Height 1.5 ft. ',
#   'Poisonous_for_pets': 'Toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/panda_plant.jpg',
#   'temperature': 'Temperatures between 60-75 ºF (15-23 ºC) are advised.'},
#  {'origin': 'South America.',
#   'Common Name': 'Parallel peperomia ',
#   'scientific_name': '. Peperomia puteolata ',
#   'Max_Growth': '45cm or longer trailing stems.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/peperomia_puteolata.jpg',
#   'temperature': 'Ideal temperatures of 65-75ºF (18-24ºC), and no lower than 50ºF (10ºC). Avoid sudden temperature drops and cold drafts.'},
#  {'origin': 'South America.',
#   'Common Name': 'Peruvian apple ',
#   'scientific_name': '. Cereus peruvianus ',
#   'Max_Growth': 'Stems can grow up to 30ft (in the wild - outdoors) and more than 3ft indoors.',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/peruvian-apple-cactus-close-up.jpg',
#   'temperature': 'Temperatures averaging 60°F/°15.5C - 75°F/23.8°C is ideal from spring to fall and a cooler 50°F/10°C – 55°F/13°, after this period. '},
#  {'origin': 'South America.',
#   'Common Name': 'Pincusion Peperomia, Bean Plant ',
#   'scientific_name': '. Peperomia ferreyrae ',
#   'Max_Growth': '15 - 20 cm tall - 10 - 25 cm spread.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/peperomia_ferreyrae.jpg',
#   'temperature': 'Ideal temperatures of 65-75ºF (18-24ºC), and no lower than 50ºF (10ºC).'},
#  {'origin': 'Mexico.',
#   'Common Name': "Rat's Tail ",
#   'scientific_name': '. Aporocactus Flagelliformis or Disocactus flagelliformis ',
#   'Max_Growth': 'Stems can grow a few feet long.',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/image-files/rats-tail-cactus-flowering.jpg',
#   'temperature': 'Temperatures averaging 50°F/10°C - 75°F/23.8°C are ideal but not below 40°F/5°C and avoid frost.'},
#  {'origin': 'South africa.',
#   'Common Name': 'Tiger Jaws ',
#   'scientific_name': '. Faucaria Tigrina ',
#   'Max_Growth': 'Diameter 8in - 20cm approx. Leaves 6in - 15 long.',
#   'Poisonous_for_pets': 'Not known.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/faucaria_tigrina.jpg',
#   'temperature': 'Temperatures averaging 70°F/21°C - 90°F/32°C are very good and not below 50°F/10°C. '},
#  {'origin': 'South America.',
#   'Common Name': 'Trailing jade, round leaf Peperomia ',
#   'scientific_name': '. Peperomia rotundifolia ',
#   'Max_Growth': '25 - 30 cm or longer trailing stems.',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/trailing_jade_peperomia_rotundifolia.jpg',
#   'temperature': 'Ideal temperatures of 65-75ºF (18-24ºC), and no lower than 50ºF (10ºC).'},
#  {'origin': 'Africa',
#   'Common Name': 'Truncate living stone ',
#   'scientific_name': '. Lithops pseudotruncatella ',
#   'Max_Growth': 'Height 1cm - 5cm max.',
#   'Poisonous_for_pets': "Not known, but it's unlikely a pet will chew on this type of foliage, although they could be curious.",
#   'big_image_url': '\n           https://www.houseplantsexpert.com/assets/images/lithops_pseudotruncatella.jpg',
#   'temperature': 'The Lithop Pseudotruncatella is a plant that is suitable for a wide range of temperatures ranging from 50°F to 100°F. However, to ensure that the plant receives a stable and consistent temperature it is best to position it in temperatures of around 65°F - 75°F where it will thrive.\n'},
#  {'origin': 'South Africa.',
#   'Common Name': 'Zebra Haworthia or Zebra Cactus ',
#   'scientific_name': '. Haworthia Fasciata and Attenuata ',
#   'Max_Growth': 'Leaves grow from 4in - 8in tall and the rosette up to about 5in in diameter. ',
#   'Poisonous_for_pets': 'Non-toxic to cats and dogs.',
#   'big_image_url': 'https://www.houseplantsexpert.com/assets/images/haworthia_attenuata.jpg',
#   'temperature': '65°F/18°C - 80°F/26°C temperatures are very good and not much below 50°F/10°C. '}]

# %% [markdown]
# # Datacleansing

# %%
# store the data into dataframe
df = pd.DataFrame(plant_info)
df.head()
# Out:
#                               origin                           Common Name  \
# 0                     South America.                            Amaryllis
# 1                    Eastern Africa.                       African violet
# 2                     South America.                   Angel wing begonia
# 3                      South Africa.  Barberton, Gerbera, Transvaal Daisy
# 4  South Mexico and Central America.                          Spider Lily
#
#               scientific_name                                 Max_Growth  \
# 0              . Hippeastrum                         Height 30 in/75 cm.
# 1              . Saintpaulia    Diameter (micro - 3in) - (large - 16in).
# 2         . Begonia coccinea             4ft tall or more if not pruned.
# 3      . -- Gebera Jamesonii                                  24in tall.
# 4  . Hymenocallis littoralis                             Height 2 - 3ft.
#
#                      Poisonous_for_pets  \
# 0               Toxic to cats and dogs.
# 1              Non toxic dogs and cats.
# 2              Toxic for cats and dogs.
# 3  Non toxic for cats, dogs and horses.
# 4                                   No.
#
#                                        big_image_url  \
# 0  https://www.houseplantsexpert.com/image-files/...
# 1  https://www.houseplantsexpert.com/assets/image...
# 2  https://www.houseplantsexpert.com/assets/image...
# 3  https://www.houseplantsexpert.com/assets/image...
# 4  https://www.houseplantsexpert.com/assets/image...
#
#                                          temperature
# 0  The amaryllis within the growing period (winte...
# 1   Room temperatures of around 65°f / 16°c --- 7...
# 2  Average room temperatures of 55 - 75°F (13 - 2...
# 3  Average temperatures of 55 - 75°F (13 - 24°C) ...
# 4  The Beach Spider Lily is capable of withstandi...

# %%
df.count()
# Out:
# origin                102
# Common Name           102
# scientific_name       102
# Max_Growth            102
# Poisonous_for_pets    102
# big_image_url         102
# temperature           102
# dtype: int64

# %%
df.dtypes
# Out:
# origin                object
# Common Name           object
# scientific_name       object
# Max_Growth            object
# Poisonous_for_pets    object
# big_image_url         object
# temperature           object
# dtype: object

# %%
df = df.dropna(how='any')
df.count()
# Out:
# origin                102
# Common Name           102
# scientific_name       102
# Max_Growth            102
# Poisonous_for_pets    102
# big_image_url         102
# temperature           102
# dtype: int64

# %%
df["origin"] = df["origin"].str.replace('.','')
df["scientific_name"]= df["scientific_name"].str.replace('.','')
df["scientific_name"]= df["scientific_name"].str.replace('--','')
df["temperature"] = df["temperature"].str.replace('°','')
df.head()
# Out:
# C:\Users\ermcg\AppData\Local\Temp/ipykernel_3528/1635514455.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["origin"] = df["origin"].str.replace('.','')
# C:\Users\ermcg\AppData\Local\Temp/ipykernel_3528/1635514455.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["scientific_name"]= df["scientific_name"].str.replace('.','')
#                              origin                           Common Name  \
# 0                     South America                            Amaryllis
# 1                    Eastern Africa                       African violet
# 2                     South America                   Angel wing begonia
# 3                      South Africa  Barberton, Gerbera, Transvaal Daisy
# 4  South Mexico and Central America                          Spider Lily
#
#              scientific_name                                 Max_Growth  \
# 0               Hippeastrum                         Height 30 in/75 cm.
# 1               Saintpaulia    Diameter (micro - 3in) - (large - 16in).
# 2          Begonia coccinea             4ft tall or more if not pruned.
# 3          Gebera Jamesonii                                  24in tall.
# 4   Hymenocallis littoralis                             Height 2 - 3ft.
#
#                      Poisonous_for_pets  \
# 0               Toxic to cats and dogs.
# 1              Non toxic dogs and cats.
# 2              Toxic for cats and dogs.
# 3  Non toxic for cats, dogs and horses.
# 4                                   No.
#
#                                        big_image_url  \
# 0  https://www.houseplantsexpert.com/image-files/...
# 1  https://www.houseplantsexpert.com/assets/image...
# 2  https://www.houseplantsexpert.com/assets/image...
# 3  https://www.houseplantsexpert.com/assets/image...
# 4  https://www.houseplantsexpert.com/assets/image...
#
#                                          temperature
# 0  The amaryllis within the growing period (winte...
# 1   Room temperatures of around 65f / 16c --- 75f...
# 2  Average room temperatures of 55 - 75F (13 - 24...
# 3  Average temperatures of 55 - 75F (13 - 24C) ar...
# 4  The Beach Spider Lily is capable of withstandi...

# %%
df.to_csv("plant_list1.csv", index=True, header = True)

# %%
countries_df = pd.read_csv("UNSD_country_to_regions.csv")
countries_df.head()
# Out:
#    Global Code Global Name  Region Code Region Name  Sub-region Code  \
# 0            1       World          2.0      Africa             15.0
# 1            1       World          2.0      Africa             15.0
# 2            1       World          2.0      Africa             15.0
# 3            1       World          2.0      Africa             15.0
# 4            1       World          2.0      Africa             15.0
#
#    Sub-region Name  Intermediate Region Code Intermediate Region Name  \
# 0  Northern Africa                       NaN                      NaN
# 1  Northern Africa                       NaN                      NaN
# 2  Northern Africa                       NaN                      NaN
# 3  Northern Africa                       NaN                      NaN
# 4  Northern Africa                       NaN                      NaN
#
#   Country or Area M49 Code ISO-alpha2 Code ISO-alpha3 Code  \
# 0         Algeria       12              DZ             DZA
# 1           Egypt      818              EG             EGY
# 2           Libya      434              LY             LBY
# 3         Morocco      504              MA             MAR
# 4           Sudan      729              SD             SDN
#
#   Least Developed Countries (LDC) Land Locked Developing Countries (LLDC)  \
# 0                             NaN                                     NaN
# 1                             NaN                                     NaN
# 2                             NaN                                     NaN
# 3                             NaN                                     NaN
# 4                               x                                     NaN
#
#   Small Island Developing States (SIDS) Unnamed: 15
# 0                                   NaN         NaN
# 1                                   NaN         NaN
# 2                                   NaN         NaN
# 3                                   NaN         NaN
# 4                                   NaN         NaN

# %%
countries_df.drop(columns=["Global Code", "Global Name", "Region Code", "Sub-region Code", "Intermediate Region Code",
                           "M49 Code", "ISO-alpha2 Code", "Least Developed Countries (LDC)", "Land Locked Developing Countries (LLDC)",
                           "Small Island Developing States (SIDS)", "Unnamed: 15"],axis=1,inplace=True)
countries_df.head()
# Out:
#   Region Name  Sub-region Name Intermediate Region Name Country or Area  \
# 0      Africa  Northern Africa                      NaN         Algeria
# 1      Africa  Northern Africa                      NaN           Egypt
# 2      Africa  Northern Africa                      NaN           Libya
# 3      Africa  Northern Africa                      NaN         Morocco
# 4      Africa  Northern Africa                      NaN           Sudan
#
#   ISO-alpha3 Code
# 0             DZA
# 1             EGY
# 2             LBY
# 3             MAR
# 4             SDN

# %%
df['origin'].unique()

# %%
#straight replacements to match country df names
#East Africa to Eastern Africa
df.loc[df['origin'] == "East Africa", 'origin'] = "Eastern Africa"
#South Africa to Southern Africa
df.loc[df['origin'] == "South Africa", 'origin'] = "Southern Africa"
#South africa to Southern Africa
df.loc[df['origin'] == "South africa", 'origin'] = "Southern Africa"
#East Asia to Eastern Asia
df.loc[df['origin'] == "East Asia", 'origin'] = "Eastern Asia"
# Southeast Asia to South-eastern Asia
df.loc[df['origin'] == "Southeast Asia", 'origin'] = "South-eastern Asia"
# North Africa to Northern Africa
df.loc[df['origin'] == "North Africa", 'origin'] = "Northern Africa"
#America to United States of America
df.loc[df['origin'] == "America", 'origin'] = "United States of America"
#South East Asia and East Australia to South-eastern Asia, Australia
df.loc[df['origin'] == "South East Asia and East Australia", 'origin'] = "South-eastern Asia, Australia"
#Canary Islands to Western Sahara
df.loc[df['origin'] == "Canary Islands", 'origin'] = "Western Sahara"
#West Indies to Caribbean
df.loc[df['origin'] == "West Indies", 'origin'] = "Caribbean"
#Southeast Asia and Western Pacific Ocean Areas to South-eastern Asia, Oceania
df.loc[df['origin'] == "Southeast Asia and Western Pacific Ocean Areas", 'origin'] = "South-eastern Asia, Oceania"
#Lord Howe Island (Australia - New South Wales State) to Australia
df.loc[df['origin'] == "Lord Howe Island (Australia - New South Wales State)", 'origin'] = "Australia"
# South-East-Asia to South-eastern Asia
df.loc[df['origin'] == "South-East-Asia", 'origin'] = "South-eastern Asia"
#Madagascar and other Indian ocean islands to Madagascar
df.loc[df['origin'] == "Madagascar and other Indian ocean islands", 'origin'] = "Madagascar"
#Taiwan to China
df.loc[df['origin'] == "Taiwan", 'origin'] = "China"
# North and South Carolina to United States of America
df.loc[df['origin'] == "North and South Carolina", 'origin'] = "United States of America"
# Africa and then developed in Thailand to the Lactea crest to Africa
df.loc[df['origin'] == "Africa and then developed in Thailand to the Lactea crest", 'origin'] = "Africa"
#South Mexico to Mexico
df.loc[df['origin'] == "South Mexico", 'origin'] = "Mexico"
#North Mexico to Mexico
df.loc[df['origin'] == "North Mexico", 'origin'] = "Mexico"
#South East Asia and Australia to South-eastern Asia, Australia
df.loc[df['origin'] == "South East Asia and Australia", 'origin'] = "South-eastern Asia, Australia"
#Japan & Taiwan to Japan, China
df.loc[df['origin'] == "Japan & Taiwan", 'origin'] = "Japan, China"
#Tropics and subtropics of Asia to South-eastern Asia, Oceania
df.loc[df['origin'] == "Tropics and subtropics of Asia", 'origin'] = "South-eastern Asia, Oceania"
#South India, Sri Lanka, Malaysia, Western Pacific Islands to India, Sri Lanka, Malaysia, Oceania
df.loc[df['origin'] == "South India, Sri Lanka, Malaysia, Western Pacific Islands", 'origin'] = "India, Sri Lanka, Malaysia, Oceania"
#Various pacific ocean areas to Oceania
df.loc[df['origin'] == "Various pacific ocean areas", 'origin'] = "Oceania"
#South Mexico to Columbia = Mexico, Central America, Columbia
df.loc[df['origin'] == "South Mexico to Columbia", 'origin'] = "Mexico, Central America, Columbia"
#China and Taiwan to China
df.loc[df['origin'] == "China and Taiwan", 'origin'] = "China"
#Peru and Ecuador to Peru, Ecuador
df.loc[df['origin'] == "Peru and Ecuador", 'origin'] = "Peru, Ecuador"
#Australia, Indonesia, China, Japan and India to Australia, Indonesia, China, Japan, India 
df.loc[df['origin'] == "Australia, Indonesia, China, Japan and India", 'origin'] = "Australia, Indonesia, China, Japan, India"
#India, Nepal, Myanmar, China, Malaysia & others to India, Nepal, Myanmar, China, Malaysia
df.loc[df['origin'] == "India, Nepal, Myanmar, China, Malaysia & others", 'origin'] = "India, Nepal, Myanmar, China, Malaysia"
# Europe, Asia and Africa to Europe, Asia, Africa
df.loc[df['origin'] == "Europe, Asia and Africa", 'origin'] = "Europe, Asia, Africa"
#Middle East, Greek Islands and elsewhere to Western Asia, Greece 
df.loc[df['origin'] == "Middle East, Greek Islands and elsewhere", 'origin'] = "Western Asia, Greece"
#South Mexico and Central America = central america, mexico
df.loc[df['origin'] == "South Mexico and Central America", 'origin'] = "Central America, Mexico"
#Mexico and Central America
df.loc[df['origin'] == "Mexico and Central America", 'origin'] = "Central America, Mexico"
# South America '
df.loc[df['origin'] == "South America ", 'origin'] = "South America"
# South and Central America
df.loc[df['origin'] == "South and Central America", 'origin'] = "South America, Central America"
# Africa 
df.loc[df['origin'] == "Africa ", 'origin'] = "Africa"
#  Mexico
df.loc[df['origin'] == " Mexico", 'origin'] = "Mexico"
#Central and South America
df.loc[df['origin'] == "Central and South America", 'origin'] = "South America, Central America"

# %%
df['origin'].unique()
# Out:
# array(['South America', 'Eastern Africa', 'Southern Africa',
#        'Central America, Mexico', 'Eastern Asia',
#        'South America, Central America', 'Western Asia, Greece', 'Brazil',
#        'Madagascar', 'China', 'South-eastern Asia', 'Peru, Ecuador',
#        'Northern Africa', 'South-eastern Asia, Australia',
#        'United States of America', 'Western Sahara', 'Japan, China',
#        'South-eastern Asia, Oceania', 'Oceania', 'Africa',
#        'Europe, Asia, Africa', 'India, Sri Lanka, Malaysia, Oceania',
#        'Caribbean', 'Southern Europe', 'Western Africa',
#        'Australia, Indonesia, China, Japan, India', 'Australia', 'Mexico',
#        'Fiji', 'Brazil ', 'India, Nepal, Myanmar, China, Malaysia',
#        'Asia', 'Mexico, Central America, Columbia'], dtype=object)

# %%
#strings to arrays
test_string = 'Australia, Indonesia, China, Japan, India'
test_list = test_string.split(',')
print(test_list)
# Out:
# ['Australia', ' Indonesia', ' China', ' Japan', ' India']

# %%
df['origin_country_list'] = ''

# %%
for i in df.index:
    to_add = []
    current_origin = df['origin'][i]
    #add another conditional to handle multiple regional names
    for x in countries_df.index:
        if countries_df['Region Name'][x] == current_origin or countries_df['Sub-region Name'][x] == current_origin or countries_df['Intermediate Region Name'][x] == current_origin or countries_df['Country or Area'][x] == current_origin:
#             print(countries_df['Country or Area'][x]) 
            to_add.append(countries_df['Country or Area'][x])#add to an array
            df['origin_country_list'][i] = to_add#add array to location in df

# %%
df.head(20)
# Out:
#                             origin  \
# 0                    South America
# 1                   Eastern Africa
# 2                    South America
# 3                  Southern Africa
# 4          Central America, Mexico
# 5                  Southern Africa
# 6                  Southern Africa
# 7                    South America
# 8                   Eastern Africa
# 9                  Southern Africa
# 10                    Eastern Asia
# 11  South America, Central America
# 12            Western Asia, Greece
# 13                          Brazil
# 14                          Brazil
# 15  South America, Central America
# 16                   South America
# 17                   South America
# 18                 Southern Africa
# 19  South America, Central America
#
#                                      Common Name  \
# 0                                     Amaryllis
# 1                                African violet
# 2                            Angel wing begonia
# 3           Barberton, Gerbera, Transvaal Daisy
# 4                                   Spider Lily
# 5   Belladonna lily, March lily and naked lady.
# 6    Bird of Paradise, Strelitzia, Crane Flower
# 7                            Blushing bromeliad
# 8                Busy Lizzie and Impatient Lucy
# 9                                    Calla lily
# 10  Coral berry, christmas berry, coral ardisia
# 11                               Corsage Orchid
# 12                    Cylamen, florist cyclamen
# 13                                Eternal Flame
# 14  False shamrock, purple sharock, wood sorrel
# 15               Flamingo flower, pigtail plant
# 16                                Flaming Sword
# 17                                    F. maple,
# 18                         Kaffir and bush lily
# 19             Lollipop and golden shrimp plant
#
#                                   scientific_name  \
# 0                                    Hippeastrum
# 1                                    Saintpaulia
# 2                               Begonia coccinea
# 3                               Gebera Jamesonii
# 4                        Hymenocallis littoralis
# 5                           Amaryllis belladonna
# 6                             Strelitzia Reginae
# 7                           Neoregelia carolinae
# 8                           Impatiens Walleriana
# 9                        Zantedeschia aethiopica
# 10                               Ardisia crenata
# 11                               Cattleya Orchid
# 12                                    C Cyclamen
# 13                              Calathea Crocata
# 14    Oxalis Triangularis [Syn Oxalis regnellii]
# 15                       Anthurium scherzerianum
# 16                             Vriesea splendens
# 17                             Abutilon hybridum
# 18                                Clivia miniata
# 19                            Pachystachys Lutea
#
#                                            Max_Growth  \
# 0                                 Height 30 in/75 cm.
# 1            Diameter (micro - 3in) - (large - 16in).
# 2                     4ft tall or more if not pruned.
# 3                                          24in tall.
# 4                                     Height 2 - 3ft.
# 5                                 Height 24 in/60 cm.
# 6            Height 6ft (can be kept to 3ft indoors).
# 7                                 Height 18 in/45 cm.
# 8                              24in (60cm) in height.
# 9                  Flower stalk 3ft (90cm) in height.
# 10                             Height 3ft, width 2ft.
# 11                                    12 - 24in tall.
# 12                                     12 inches tall
# 13                                   Height 1 - 2ft.
# 14                                         12in tall.
# 15                          12 - 18 inches in height.
# 16          Height 18 in/45 cm, diameter 10 in/25 cm.
# 17                              Height 5 ft or more.
# 18                               18 inches in height.
# 19  Height 1 - 2ft indoors, outdoors 4ft. Spread 2...
#
#                       Poisonous_for_pets  \
# 0                Toxic to cats and dogs.
# 1               Non toxic dogs and cats.
# 2               Toxic for cats and dogs.
# 3   Non toxic for cats, dogs and horses.
# 4                                    No.
# 5                Toxic to cats and dogs.
# 6            Mildly toxic for cats, dogs
# 7               Non toxic for cats, dogs
# 8            Non-toxic to cats and dogs.
# 9                Toxic to cats and dogs.
# 10                            Not known.
# 11  Non toxic for cats, dogs and horses.
# 12               Toxic to cats and dogs.
# 13           Non-toxic to cats and dogs.
# 14               Toxic to cats and dogs.
# 15               Toxic to cats and dogs.
# 16           Non-Toxic to cats and dogs.
# 17                            Not known.
# 18               Toxic to cats and dogs.
# 19                            Not known.
#
#                                         big_image_url  \
# 0   https://www.houseplantsexpert.com/image-files/...
# 1   https://www.houseplantsexpert.com/assets/image...
# 2   https://www.houseplantsexpert.com/assets/image...
# 3   https://www.houseplantsexpert.com/assets/image...
# 4   https://www.houseplantsexpert.com/assets/image...
# 5   https://www.houseplantsexpert.com/image-files/...
# 6   https://www.houseplantsexpert.com/assets/image...
# 7   https://www.houseplantsexpert.com/image-files/...
# 8   https://www.houseplantsexpert.com/image-files/...
# 9   https://www.houseplantsexpert.com/image-files/...
# 10  https://www.houseplantsexpert.com/images/ardis...
# 11  https://www.houseplantsexpert.com/assets/image...
# 12  https://www.houseplantsexpert.com/assets/image...
# 13  https://www.houseplantsexpert.com/assets/image...
# 14  https://www.houseplantsexpert.com/image-files/...
# 15  https://www.houseplantsexpert.com/image-files/...
# 16  https://www.houseplantsexpert.com/image-files/...
# 17  https://www.houseplantsexpert.com/image-files/...
# 18  https://www.houseplantsexpert.com/image-files/...
# 19  https://www.houseplantsexpert.com/image-files/...
#
#                                           temperature  \
# 0   The amaryllis within the growing period (winte...
# 1    Room temperatures of around 65f / 16c --- 75f...
# 2   Average room temperatures of 55 - 75F (13 - 24...
# 3   Average temperatures of 55 - 75F (13 - 24C) ar...
# 4   The Beach Spider Lily is capable of withstandi...
# 5   Temperatures from 65 - 75Ff (18 - 24c) are bes...
# 6   The Bird of Paradise requires moderate tempera...
# 7    Average to just above average temperatures of...
# 8   Average room temperatures from 65F/18.3C - 75F...
# 9   These flowers can be rather picky about their ...
# 10  Average warmth is fine of approximately 60-75F...
# 11  They do well in temperatures varying from 55 d...
# 12  Cool temperatures from 50F/10C - 65F/18C are i...
# 13  It likes humidity and warmth. Not lower than 6...
# 14  Temperature: Between 60 - 70F (15 - 21C) "no h...
# 15  Average room temperatures from 65F/18.3C - 75F...
# 16  Temperature:To bring them in to flower you may...
# 17  They thrive in summer conditions and prefer te...
# 18  Temperatures from cool to average room 60F/15....
# 19  Average room temperatures of around 65f / 16c ...
#
#                                   origin_country_list
# 0   [Argentina, Bolivia (Plurinational State of), ...
# 1   [British Indian Ocean Territory, Burundi, Como...
# 2   [Argentina, Bolivia (Plurinational State of), ...
# 3   [Botswana, Eswatini, Lesotho, Namibia, South A...
# 4
# 5   [Botswana, Eswatini, Lesotho, Namibia, South A...
# 6   [Botswana, Eswatini, Lesotho, Namibia, South A...
# 7   [Argentina, Bolivia (Plurinational State of), ...
# 8   [British Indian Ocean Territory, Burundi, Como...
# 9   [Botswana, Eswatini, Lesotho, Namibia, South A...
# 10  [China, China, China, Democratic People's Repu...
# 11
# 12
# 13                                           [Brazil]
# 14                                           [Brazil]
# 15
# 16  [Argentina, Bolivia (Plurinational State of), ...
# 17  [Argentina, Bolivia (Plurinational State of), ...
# 18  [Botswana, Eswatini, Lesotho, Namibia, South A...
# 19

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float

# %%
Base = declarative_base()

# %%
class Country(Base):
    __tablename__ = 'countries'
    id = Column(Integer, primary_key=True)
    country = Column(String(100))
    intermediate_region = Column(String(100))
    sub_region = Column(String(100))
    region = Column(String(100))

# %%
#Create db connection
engine = create_engine("sqlite:///countries.sqlite")
conn = engine.connect()

# %%
#creates tables from python classes
Base.metadata.create_all(engine)

# %%
#create connection to edit db
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
#for loop this with scraped data to add to db?
for row in countries_df.itertuples():
    country_toadd = Country(country=row[4], intermediate_region=row[3], sub_region=row[2], region=row[1])
    session.add(country_toadd)

# %%
#push additions to db
session.commit()

# %%
#close session
session.close()

# %%
session.query(Country.country).all()
